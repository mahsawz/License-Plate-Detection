# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras as K
print(tf.__version__)
print(tf.config.list_physical_devices())
# !pwd
# Out:
# 2.4.1
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# /content

# %%
def recall_m(y_true, y_pred):
    K = tf.keras.backend
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    K = tf.keras.backend
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    K = tf.keras.backend
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# %cd /
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# !ln -s /content/gdrive/My\ Drive/cv_final_project /gd
# !ls /gd
# !mkdir -p /w
# %cd /w
# Out:
# /
# Mounted at /content/gdrive
# data_aug.7z		 v_3_xception_sgd.ipynb
# Dataset.7z		 v_4_xception_adam.ipynb
# v_1_resnet50_ft40.ipynb  v_5_xception_adam_lighting_aug.ipynb
# v_2_resnet50.ipynb
# /w

# %%
# !cp /gd/data_aug.7z /w
!7z x /w/data_aug.7z -o/w/Dataset
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 157905383 bytes (151 MiB)
#
# Extracting archive: /w/data_aug.7z
# --
# Path = /w/data_aug.7z
# Type = 7z
# Physical Size = 157905383
# Headers Size = 69525
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 4
# Files: 7013
# Size:       163404370
# Compressed: 157905383

# %%
# !ls Dataset/data_aug
# Out:
# 0  1  2

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.xception import preprocess_input

img_height, img_width = 224, 224
batch_size = 64
nb_epochs = 60
nb_classes = 3

train_data_dir = '/w/Dataset/data_aug'

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    shear_range=0.25,
    width_shift_range=0.25,
    height_shift_range=0.25,
    zoom_range=0.2,
    rotation_range=40,
    validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 5612 images belonging to 3 classes.
# Found 1401 images belonging to 3 classes.

# %%
from tensorflow.keras.applications import ResNet50, ResNet50V2, Xception
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, AveragePooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam, Adadelta, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

def build_model_fine_tune():
    baseModel = Xception(
        include_top=False,
        weights="imagenet",
        input_tensor=Input(shape=(img_height, img_width, 3)),
        pooling='avg',
    )
    
    # for layer in baseModel.layers:
    #     layer.trainable = False
    # for layer in baseModel.layers[-40:]:
    #     layer.trainable = True

    headModel = baseModel.output
    headModel = Dropout(0.2)(headModel)
    headModel = Dense(1024, activation="relu")(headModel)
    headModel = Dropout(0.2)(headModel)
    headModel = Dense(1024, activation="relu")(headModel)
    headModel = Dropout(0.2)(headModel)
    headModel = Dense(512, activation="relu")(headModel)
    headModel = Dropout(0.2)(headModel)
    headModel = Dense(512, activation="relu")(headModel)
    headModel = Dropout(0.2)(headModel)
    headModel = Dense(nb_classes, activation="softmax")(headModel)
    
    model = Model(inputs=baseModel.input, outputs=headModel)

    return model


learning_rate = 0.0001
weights = os.path.join('', 'weightsv5.h5')
callbacks = [ EarlyStopping(monitor='val_f1_m', patience=20, verbose=0, mode='max'), 
              ModelCheckpoint(weights, monitor='val_f1_m', save_best_only=True, verbose=1, mode='max'),
              ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=20, verbose=0, mode='min', min_delta=0.0001, cooldown=0, min_lr=0)]
loss = CategoricalCrossentropy()
# optimizer = SGD(lr=1e-2, momentum=0.9, decay=1e-2/40)
optimizer = Adam(lr=learning_rate)
model = build_model_fine_tune()
model.compile(
    loss=loss, 
    optimizer='adam', 
    metrics=['accuracy', f1_m, precision_m, recall_m],
)

history = model.fit(
    train_generator, 
    validation_data=validation_generator, 
    epochs=nb_epochs, 
    batch_size=batch_size, 
    callbacks=callbacks,
)
# Out:
# Epoch 1/60
# 88/88 [==============================] - 138s 2s/step - loss: 0.6045 - accuracy: 0.7412 - f1_m: 0.6972 - precision_m: 0.8286 - recall_m: 0.6174 - val_loss: 1.3199 - val_accuracy: 0.7966 - val_f1_m: 0.7967 - val_precision_m: 0.8052 - val_recall_m: 0.7885
#
# Epoch 00001: val_f1_m improved from -inf to 0.79668, saving model to weightsv5.h5
# Epoch 2/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.2440 - accuracy: 0.8982 - f1_m: 0.8981 - precision_m: 0.9159 - recall_m: 0.8814 - val_loss: 0.7424 - val_accuracy: 0.8508 - val_f1_m: 0.8558 - val_precision_m: 0.8624 - val_recall_m: 0.8494
#
# Epoch 00002: val_f1_m improved from 0.79668 to 0.85582, saving model to weightsv5.h5
# Epoch 3/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.1582 - accuracy: 0.9511 - f1_m: 0.9507 - precision_m: 0.9566 - recall_m: 0.9449 - val_loss: 0.5688 - val_accuracy: 0.8908 - val_f1_m: 0.8901 - val_precision_m: 0.8946 - val_recall_m: 0.8857
#
# Epoch 00003: val_f1_m improved from 0.85582 to 0.89007, saving model to weightsv5.h5
# Epoch 4/60
# 88/88 [==============================] - 129s 1s/step - loss: 0.1269 - accuracy: 0.9632 - f1_m: 0.9626 - precision_m: 0.9651 - recall_m: 0.9602 - val_loss: 0.1852 - val_accuracy: 0.9707 - val_f1_m: 0.9702 - val_precision_m: 0.9706 - val_recall_m: 0.9698
#
# Epoch 00004: val_f1_m improved from 0.89007 to 0.97020, saving model to weightsv5.h5
# Epoch 5/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0993 - accuracy: 0.9661 - f1_m: 0.9661 - precision_m: 0.9685 - recall_m: 0.9637 - val_loss: 0.7444 - val_accuracy: 0.7338 - val_f1_m: 0.7244 - val_precision_m: 0.7627 - val_recall_m: 0.6901
#
# Epoch 00005: val_f1_m did not improve from 0.97020
# Epoch 6/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.1392 - accuracy: 0.9609 - f1_m: 0.9596 - precision_m: 0.9641 - recall_m: 0.9552 - val_loss: 0.1660 - val_accuracy: 0.9565 - val_f1_m: 0.9567 - val_precision_m: 0.9598 - val_recall_m: 0.9536
#
# Epoch 00006: val_f1_m did not improve from 0.97020
# Epoch 7/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0641 - accuracy: 0.9782 - f1_m: 0.9772 - precision_m: 0.9783 - recall_m: 0.9760 - val_loss: 0.0606 - val_accuracy: 0.9793 - val_f1_m: 0.9794 - val_precision_m: 0.9801 - val_recall_m: 0.9787
#
# Epoch 00007: val_f1_m improved from 0.97020 to 0.97938, saving model to weightsv5.h5
# Epoch 8/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0857 - accuracy: 0.9741 - f1_m: 0.9731 - precision_m: 0.9752 - recall_m: 0.9710 - val_loss: 0.2700 - val_accuracy: 0.9529 - val_f1_m: 0.9518 - val_precision_m: 0.9532 - val_recall_m: 0.9505
#
# Epoch 00008: val_f1_m did not improve from 0.97938
# Epoch 9/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0898 - accuracy: 0.9756 - f1_m: 0.9740 - precision_m: 0.9766 - recall_m: 0.9714 - val_loss: 0.0960 - val_accuracy: 0.9729 - val_f1_m: 0.9712 - val_precision_m: 0.9741 - val_recall_m: 0.9684
#
# Epoch 00009: val_f1_m did not improve from 0.97938
# Epoch 10/60
# 88/88 [==============================] - 129s 1s/step - loss: 0.0634 - accuracy: 0.9819 - f1_m: 0.9819 - precision_m: 0.9833 - recall_m: 0.9806 - val_loss: 0.0507 - val_accuracy: 0.9843 - val_f1_m: 0.9843 - val_precision_m: 0.9850 - val_recall_m: 0.9836
#
# Epoch 00010: val_f1_m improved from 0.97938 to 0.98428, saving model to weightsv5.h5
# Epoch 11/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0713 - accuracy: 0.9830 - f1_m: 0.9825 - precision_m: 0.9837 - recall_m: 0.9814 - val_loss: 0.1914 - val_accuracy: 0.9465 - val_f1_m: 0.9463 - val_precision_m: 0.9484 - val_recall_m: 0.9443
#
# Epoch 00011: val_f1_m did not improve from 0.98428
# Epoch 12/60
# 88/88 [==============================] - 129s 1s/step - loss: 0.0570 - accuracy: 0.9841 - f1_m: 0.9841 - precision_m: 0.9859 - recall_m: 0.9824 - val_loss: 0.0807 - val_accuracy: 0.9886 - val_f1_m: 0.9886 - val_precision_m: 0.9886 - val_recall_m: 0.9886
#
# Epoch 00012: val_f1_m improved from 0.98428 to 0.98864, saving model to weightsv5.h5
# Epoch 13/60
# 88/88 [==============================] - 129s 1s/step - loss: 0.0491 - accuracy: 0.9847 - f1_m: 0.9846 - precision_m: 0.9848 - recall_m: 0.9843 - val_loss: 0.0577 - val_accuracy: 0.9772 - val_f1_m: 0.9771 - val_precision_m: 0.9771 - val_recall_m: 0.9771
#
# Epoch 00013: val_f1_m did not improve from 0.98864
# Epoch 14/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0536 - accuracy: 0.9858 - f1_m: 0.9859 - precision_m: 0.9878 - recall_m: 0.9841 - val_loss: 0.0534 - val_accuracy: 0.9872 - val_f1_m: 0.9876 - val_precision_m: 0.9879 - val_recall_m: 0.9872
#
# Epoch 00014: val_f1_m did not improve from 0.98864
# Epoch 15/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0260 - accuracy: 0.9919 - f1_m: 0.9921 - precision_m: 0.9922 - recall_m: 0.9919 - val_loss: 0.0361 - val_accuracy: 0.9893 - val_f1_m: 0.9893 - val_precision_m: 0.9893 - val_recall_m: 0.9893
#
# Epoch 00015: val_f1_m improved from 0.98864 to 0.98926, saving model to weightsv5.h5
# Epoch 16/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0264 - accuracy: 0.9924 - f1_m: 0.9923 - precision_m: 0.9927 - recall_m: 0.9919 - val_loss: 0.0311 - val_accuracy: 0.9907 - val_f1_m: 0.9907 - val_precision_m: 0.9907 - val_recall_m: 0.9907
#
# Epoch 00016: val_f1_m improved from 0.98926 to 0.99068, saving model to weightsv5.h5
# Epoch 17/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0530 - accuracy: 0.9870 - f1_m: 0.9871 - precision_m: 0.9876 - recall_m: 0.9866 - val_loss: 0.0918 - val_accuracy: 0.9707 - val_f1_m: 0.9707 - val_precision_m: 0.9707 - val_recall_m: 0.9707
#
# Epoch 00017: val_f1_m did not improve from 0.99068
# Epoch 18/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0412 - accuracy: 0.9885 - f1_m: 0.9883 - precision_m: 0.9885 - recall_m: 0.9880 - val_loss: 0.0477 - val_accuracy: 0.9872 - val_f1_m: 0.9874 - val_precision_m: 0.9878 - val_recall_m: 0.9870
#
# Epoch 00018: val_f1_m did not improve from 0.99068
# Epoch 19/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0201 - accuracy: 0.9944 - f1_m: 0.9946 - precision_m: 0.9947 - recall_m: 0.9944 - val_loss: 0.0223 - val_accuracy: 0.9907 - val_f1_m: 0.9908 - val_precision_m: 0.9908 - val_recall_m: 0.9908
#
# Epoch 00019: val_f1_m improved from 0.99068 to 0.99077, saving model to weightsv5.h5
# Epoch 20/60
# 88/88 [==============================] - 129s 1s/step - loss: 0.0416 - accuracy: 0.9864 - f1_m: 0.9867 - precision_m: 0.9872 - recall_m: 0.9863 - val_loss: 0.1202 - val_accuracy: 0.9643 - val_f1_m: 0.9640 - val_precision_m: 0.9664 - val_recall_m: 0.9616
#
# Epoch 00020: val_f1_m did not improve from 0.99077
# Epoch 21/60
# 88/88 [==============================] - 129s 1s/step - loss: 0.0507 - accuracy: 0.9837 - f1_m: 0.9838 - precision_m: 0.9839 - recall_m: 0.9837 - val_loss: 0.0385 - val_accuracy: 0.9872 - val_f1_m: 0.9875 - val_precision_m: 0.9878 - val_recall_m: 0.9871
#
# Epoch 00021: val_f1_m did not improve from 0.99077
# Epoch 22/60
# 88/88 [==============================] - 129s 1s/step - loss: 0.0323 - accuracy: 0.9904 - f1_m: 0.9907 - precision_m: 0.9910 - recall_m: 0.9903 - val_loss: 0.1126 - val_accuracy: 0.9743 - val_f1_m: 0.9739 - val_precision_m: 0.9757 - val_recall_m: 0.9722
#
# Epoch 00022: val_f1_m did not improve from 0.99077
# Epoch 23/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0658 - accuracy: 0.9821 - f1_m: 0.9824 - precision_m: 0.9838 - recall_m: 0.9810 - val_loss: 0.1718 - val_accuracy: 0.9586 - val_f1_m: 0.9593 - val_precision_m: 0.9607 - val_recall_m: 0.9579
#
# Epoch 00023: val_f1_m did not improve from 0.99077
# Epoch 24/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0529 - accuracy: 0.9870 - f1_m: 0.9872 - precision_m: 0.9884 - recall_m: 0.9860 - val_loss: 0.0307 - val_accuracy: 0.9893 - val_f1_m: 0.9892 - val_precision_m: 0.9899 - val_recall_m: 0.9885
#
# Epoch 00024: val_f1_m did not improve from 0.99077
# Epoch 25/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0463 - accuracy: 0.9863 - f1_m: 0.9862 - precision_m: 0.9864 - recall_m: 0.9860 - val_loss: 0.0620 - val_accuracy: 0.9786 - val_f1_m: 0.9786 - val_precision_m: 0.9799 - val_recall_m: 0.9772
#
# Epoch 00025: val_f1_m did not improve from 0.99077
# Epoch 26/60
# 88/88 [==============================] - 129s 1s/step - loss: 0.0420 - accuracy: 0.9886 - f1_m: 0.9886 - precision_m: 0.9889 - recall_m: 0.9884 - val_loss: 0.0692 - val_accuracy: 0.9786 - val_f1_m: 0.9787 - val_precision_m: 0.9787 - val_recall_m: 0.9787
#
# Epoch 00026: val_f1_m did not improve from 0.99077
# Epoch 27/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0490 - accuracy: 0.9878 - f1_m: 0.9877 - precision_m: 0.9881 - recall_m: 0.9874 - val_loss: 0.0241 - val_accuracy: 0.9900 - val_f1_m: 0.9901 - val_precision_m: 0.9901 - val_recall_m: 0.9901
#
# Epoch 00027: val_f1_m did not improve from 0.99077
# Epoch 28/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0291 - accuracy: 0.9928 - f1_m: 0.9930 - precision_m: 0.9932 - recall_m: 0.9927 - val_loss: 0.0281 - val_accuracy: 0.9907 - val_f1_m: 0.9908 - val_precision_m: 0.9908 - val_recall_m: 0.9908
#
# Epoch 00028: val_f1_m did not improve from 0.99077
# Epoch 29/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0251 - accuracy: 0.9934 - f1_m: 0.9935 - precision_m: 0.9938 - recall_m: 0.9932 - val_loss: 0.0380 - val_accuracy: 0.9914 - val_f1_m: 0.9915 - val_precision_m: 0.9922 - val_recall_m: 0.9908
#
# Epoch 00029: val_f1_m improved from 0.99077 to 0.99147, saving model to weightsv5.h5
# Epoch 30/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0203 - accuracy: 0.9952 - f1_m: 0.9951 - precision_m: 0.9956 - recall_m: 0.9945 - val_loss: 0.0961 - val_accuracy: 0.9700 - val_f1_m: 0.9714 - val_precision_m: 0.9728 - val_recall_m: 0.9701
#
# Epoch 00030: val_f1_m did not improve from 0.99147
# Epoch 31/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0420 - accuracy: 0.9888 - f1_m: 0.9885 - precision_m: 0.9896 - recall_m: 0.9874 - val_loss: 0.1414 - val_accuracy: 0.9358 - val_f1_m: 0.9370 - val_precision_m: 0.9411 - val_recall_m: 0.9330
#
# Epoch 00031: val_f1_m did not improve from 0.99147
# Epoch 32/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0523 - accuracy: 0.9869 - f1_m: 0.9873 - precision_m: 0.9880 - recall_m: 0.9865 - val_loss: 0.0414 - val_accuracy: 0.9836 - val_f1_m: 0.9850 - val_precision_m: 0.9871 - val_recall_m: 0.9829
#
# Epoch 00032: val_f1_m did not improve from 0.99147
# Epoch 33/60
# 88/88 [==============================] - 126s 1s/step - loss: 0.0226 - accuracy: 0.9928 - f1_m: 0.9933 - precision_m: 0.9937 - recall_m: 0.9928 - val_loss: 0.0411 - val_accuracy: 0.9872 - val_f1_m: 0.9875 - val_precision_m: 0.9878 - val_recall_m: 0.9871
#
# Epoch 00033: val_f1_m did not improve from 0.99147
# Epoch 34/60
# 88/88 [==============================] - 127s 1s/step - loss: 0.0416 - accuracy: 0.9874 - f1_m: 0.9870 - precision_m: 0.9880 - recall_m: 0.9861 - val_loss: 0.0664 - val_accuracy: 0.9822 - val_f1_m: 0.9823 - val_precision_m: 0.9834 - val_recall_m: 0.9813
#
# Epoch 00034: val_f1_m did not improve from 0.99147
# Epoch 35/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0345 - accuracy: 0.9893 - f1_m: 0.9903 - precision_m: 0.9914 - recall_m: 0.9891 - val_loss: 0.0524 - val_accuracy: 0.9764 - val_f1_m: 0.9764 - val_precision_m: 0.9771 - val_recall_m: 0.9757
#
# Epoch 00035: val_f1_m did not improve from 0.99147
# Epoch 36/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0669 - accuracy: 0.9811 - f1_m: 0.9812 - precision_m: 0.9830 - recall_m: 0.9794 - val_loss: 0.0308 - val_accuracy: 0.9907 - val_f1_m: 0.9903 - val_precision_m: 0.9914 - val_recall_m: 0.9893
#
# Epoch 00036: val_f1_m did not improve from 0.99147
# Epoch 37/60
# 88/88 [==============================] - 127s 1s/step - loss: 0.0174 - accuracy: 0.9958 - f1_m: 0.9958 - precision_m: 0.9961 - recall_m: 0.9955 - val_loss: 0.0200 - val_accuracy: 0.9950 - val_f1_m: 0.9949 - val_precision_m: 0.9949 - val_recall_m: 0.9949
#
# Epoch 00037: val_f1_m improved from 0.99147 to 0.99494, saving model to weightsv5.h5
# Epoch 38/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0300 - accuracy: 0.9949 - f1_m: 0.9953 - precision_m: 0.9956 - recall_m: 0.9950 - val_loss: 0.0165 - val_accuracy: 0.9943 - val_f1_m: 0.9942 - val_precision_m: 0.9942 - val_recall_m: 0.9942
#
# Epoch 00038: val_f1_m did not improve from 0.99494
# Epoch 39/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0171 - accuracy: 0.9940 - f1_m: 0.9944 - precision_m: 0.9948 - recall_m: 0.9940 - val_loss: 0.0283 - val_accuracy: 0.9929 - val_f1_m: 0.9914 - val_precision_m: 0.9935 - val_recall_m: 0.9893
#
# Epoch 00039: val_f1_m did not improve from 0.99494
# Epoch 40/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0155 - accuracy: 0.9966 - f1_m: 0.9963 - precision_m: 0.9968 - recall_m: 0.9959 - val_loss: 0.0500 - val_accuracy: 0.9907 - val_f1_m: 0.9904 - val_precision_m: 0.9915 - val_recall_m: 0.9893
#
# Epoch 00040: val_f1_m did not improve from 0.99494
# Epoch 41/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0243 - accuracy: 0.9928 - f1_m: 0.9929 - precision_m: 0.9934 - recall_m: 0.9924 - val_loss: 0.0756 - val_accuracy: 0.9864 - val_f1_m: 0.9871 - val_precision_m: 0.9878 - val_recall_m: 0.9864
#
# Epoch 00041: val_f1_m did not improve from 0.99494
# Epoch 42/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0403 - accuracy: 0.9878 - f1_m: 0.9882 - precision_m: 0.9894 - recall_m: 0.9870 - val_loss: 0.0280 - val_accuracy: 0.9921 - val_f1_m: 0.9922 - val_precision_m: 0.9922 - val_recall_m: 0.9922
#
# Epoch 00042: val_f1_m did not improve from 0.99494
# Epoch 43/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0281 - accuracy: 0.9944 - f1_m: 0.9945 - precision_m: 0.9947 - recall_m: 0.9944 - val_loss: 0.0227 - val_accuracy: 0.9943 - val_f1_m: 0.9943 - val_precision_m: 0.9943 - val_recall_m: 0.9943
#
# Epoch 00043: val_f1_m did not improve from 0.99494
# Epoch 44/60
# 88/88 [==============================] - 127s 1s/step - loss: 0.0184 - accuracy: 0.9953 - f1_m: 0.9953 - precision_m: 0.9954 - recall_m: 0.9952 - val_loss: 0.0144 - val_accuracy: 0.9936 - val_f1_m: 0.9940 - val_precision_m: 0.9950 - val_recall_m: 0.9929
#
# Epoch 00044: val_f1_m did not improve from 0.99494
# Epoch 45/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0202 - accuracy: 0.9947 - f1_m: 0.9949 - precision_m: 0.9953 - recall_m: 0.9946 - val_loss: 0.0162 - val_accuracy: 0.9957 - val_f1_m: 0.9953 - val_precision_m: 0.9957 - val_recall_m: 0.9949
#
# Epoch 00045: val_f1_m improved from 0.99494 to 0.99529, saving model to weightsv5.h5
# Epoch 46/60
# 88/88 [==============================] - 129s 1s/step - loss: 0.0357 - accuracy: 0.9898 - f1_m: 0.9898 - precision_m: 0.9910 - recall_m: 0.9887 - val_loss: 0.4970 - val_accuracy: 0.9465 - val_f1_m: 0.9467 - val_precision_m: 0.9471 - val_recall_m: 0.9464
#
# Epoch 00046: val_f1_m did not improve from 0.99529
# Epoch 47/60
# 88/88 [==============================] - 130s 1s/step - loss: 0.0380 - accuracy: 0.9894 - f1_m: 0.9892 - precision_m: 0.9897 - recall_m: 0.9887 - val_loss: 0.1069 - val_accuracy: 0.9743 - val_f1_m: 0.9741 - val_precision_m: 0.9776 - val_recall_m: 0.9706
#
# Epoch 00047: val_f1_m did not improve from 0.99529
# Epoch 48/60
# 88/88 [==============================] - 129s 1s/step - loss: 0.0374 - accuracy: 0.9887 - f1_m: 0.9889 - precision_m: 0.9899 - recall_m: 0.9879 - val_loss: 0.0483 - val_accuracy: 0.9864 - val_f1_m: 0.9861 - val_precision_m: 0.9864 - val_recall_m: 0.9857
#
# Epoch 00048: val_f1_m did not improve from 0.99529
# Epoch 49/60
# 88/88 [==============================] - 130s 1s/step - loss: 0.0152 - accuracy: 0.9960 - f1_m: 0.9959 - precision_m: 0.9960 - recall_m: 0.9957 - val_loss: 0.0126 - val_accuracy: 0.9943 - val_f1_m: 0.9943 - val_precision_m: 0.9943 - val_recall_m: 0.9943
#
# Epoch 00049: val_f1_m did not improve from 0.99529
# Epoch 50/60
# 88/88 [==============================] - 129s 1s/step - loss: 0.0186 - accuracy: 0.9938 - f1_m: 0.9938 - precision_m: 0.9938 - recall_m: 0.9938 - val_loss: 0.0340 - val_accuracy: 0.9879 - val_f1_m: 0.9883 - val_precision_m: 0.9886 - val_recall_m: 0.9879
#
# Epoch 00050: val_f1_m did not improve from 0.99529
# Epoch 51/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0228 - accuracy: 0.9928 - f1_m: 0.9928 - precision_m: 0.9929 - recall_m: 0.9927 - val_loss: 0.0336 - val_accuracy: 0.9907 - val_f1_m: 0.9910 - val_precision_m: 0.9914 - val_recall_m: 0.9907
#
# Epoch 00051: val_f1_m did not improve from 0.99529
# Epoch 52/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0380 - accuracy: 0.9898 - f1_m: 0.9896 - precision_m: 0.9898 - recall_m: 0.9893 - val_loss: 0.0328 - val_accuracy: 0.9964 - val_f1_m: 0.9964 - val_precision_m: 0.9964 - val_recall_m: 0.9964
#
# Epoch 00052: val_f1_m improved from 0.99529 to 0.99645, saving model to weightsv5.h5
# Epoch 53/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0237 - accuracy: 0.9944 - f1_m: 0.9947 - precision_m: 0.9953 - recall_m: 0.9942 - val_loss: 0.0258 - val_accuracy: 0.9886 - val_f1_m: 0.9885 - val_precision_m: 0.9885 - val_recall_m: 0.9885
#
# Epoch 00053: val_f1_m did not improve from 0.99645
# Epoch 54/60
# 88/88 [==============================] - 128s 1s/step - loss: 0.0339 - accuracy: 0.9897 - f1_m: 0.9901 - precision_m: 0.9907 - recall_m: 0.9894 - val_loss: 0.0288 - val_accuracy: 0.9950 - val_f1_m: 0.9950 - val_precision_m: 0.9950 - val_recall_m: 0.9950
#
# Epoch 00054: val_f1_m did not improve from 0.99645
# Epoch 55/60
# 88/88 [==============================] - 129s 1s/step - loss: 0.0072 - accuracy: 0.9979 - f1_m: 0.9979 - precision_m: 0.9979 - recall_m: 0.9979 - val_loss: 0.0350 - val_accuracy: 0.9893 - val_f1_m: 0.9890 - val_precision_m: 0.9893 - val_recall_m: 0.9886
#
# Epoch 00055: val_f1_m did not improve from 0.99645
# Epoch 56/60
# 88/88 [==============================] - 130s 1s/step - loss: 0.0258 - accuracy: 0.9927 - f1_m: 0.9927 - precision_m: 0.9930 - recall_m: 0.9924 - val_loss: 0.0221 - val_accuracy: 0.9964 - val_f1_m: 0.9961 - val_precision_m: 0.9964 - val_recall_m: 0.9957
#
# Epoch 00056: val_f1_m did not improve from 0.99645
# Epoch 57/60
# 88/88 [==============================] - 130s 1s/step - loss: 0.0253 - accuracy: 0.9921 - f1_m: 0.9925 - precision_m: 0.9931 - recall_m: 0.9920 - val_loss: 0.0144 - val_accuracy: 0.9957 - val_f1_m: 0.9956 - val_precision_m: 0.9956 - val_recall_m: 0.9956
#
# Epoch 00057: val_f1_m did not improve from 0.99645
# Epoch 58/60
# 88/88 [==============================] - 130s 1s/step - loss: 0.0217 - accuracy: 0.9939 - f1_m: 0.9939 - precision_m: 0.9939 - recall_m: 0.9939 - val_loss: 0.0130 - val_accuracy: 0.9950 - val_f1_m: 0.9950 - val_precision_m: 0.9950 - val_recall_m: 0.9950
#
# Epoch 00058: val_f1_m did not improve from 0.99645
# Epoch 59/60
# 88/88 [==============================] - 130s 1s/step - loss: 0.0133 - accuracy: 0.9973 - f1_m: 0.9973 - precision_m: 0.9973 - recall_m: 0.9973 - val_loss: 0.0487 - val_accuracy: 0.9900 - val_f1_m: 0.9899 - val_precision_m: 0.9899 - val_recall_m: 0.9899
#
# Epoch 00059: val_f1_m did not improve from 0.99645
# Epoch 60/60
# 88/88 [==============================] - 129s 1s/step - loss: 0.0111 - accuracy: 0.9946 - f1_m: 0.9948 - precision_m: 0.9950 - recall_m: 0.9946 - val_loss: 0.0206 - val_accuracy: 0.9921 - val_f1_m: 0.9922 - val_precision_m: 0.9922 - val_recall_m: 0.9922
#
# Epoch 00060: val_f1_m did not improve from 0.99645

# %%
best_model = tf.keras.models.load_model('/w/weightsv5.h5', custom_objects={'f1_m':f1_m, 'precision_m':precision_m, 'recall_m':recall_m})
best_model.compile(
    loss=loss, 
    optimizer='adam', 
    metrics=['accuracy', f1_m, precision_m, recall_m],
)

# %%
test_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
  )
best_model.evaluate(test_generator, batch_size=batch_size)
# Out:
# Found 1401 images belonging to 3 classes.
# 22/22 [==============================] - 19s 834ms/step - loss: 0.0172 - accuracy: 0.9964 - f1_m: 0.9968 - precision_m: 0.9972 - recall_m: 0.9964
# [0.01716098189353943,
#  0.9964311122894287,
#  0.9968011975288391,
#  0.9971590638160706,
#  0.9964488744735718]

# %%
best_model.save("/w/modelv5.h5")

# %%
download("/gd/modelv5.h5")

# %%
from sklearn.metrics import classification_report, confusion_matrix

test_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
  )

Y_pred = best_model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(test_generator.classes, y_pred))
print('Classification Report')
target_names = ['0', '1', '2']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Found 1401 images belonging to 3 classes.
# Confusion Matrix
# [[951   6   1]
#  [  2 147   1]
#  [  0   0 293]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       958
#            1       0.96      0.98      0.97       150
#            2       0.99      1.00      1.00       293
#
#     accuracy                           0.99      1401
#    macro avg       0.98      0.99      0.99      1401
# weighted avg       0.99      0.99      0.99      1401

# %%
# !cp /gd/Dataset.7z /w
!7z x /w/Dataset.7z -o/w/OrgDataset
# !ls /w/OrgDataset
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 60678820 bytes (58 MiB)
#
# Extracting archive: /w/Dataset.7z
# --
# Path = /w/Dataset.7z
# Type = 7z
# Physical Size = 60678820
# Headers Size = 27545
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 3
# Files: 2727
# Size:       62459394
# Compressed: 60678820
# 0  1  2

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.xception import preprocess_input

img_height, img_width = 224, 224
batch_size = 64
nb_epochs = 60
nb_classes = 3

org_data_dir = '/w/OrgDataset'

validation_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    zoom_range=0.2,
    horizontal_flip=False,
    rotation_range=40,
    validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation')
