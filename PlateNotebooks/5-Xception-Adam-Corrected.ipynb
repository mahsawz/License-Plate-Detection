# %% [markdown]
# ## Import some prerequirement

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.xception import preprocess_input
from tensorflow.keras.applications import ResNet50, ResNet50V2, Xception
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, AveragePooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam, Adadelta, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# ## Unzipping data

# %% [markdown]
# ### 1. Mount your drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Unzip data

# %%
os.chdir('/content/drive/MyDrive/PlateDataset/')
!7z x correct_data.7z -ocorrect_data
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 60689089 bytes (58 MiB)
#
# Extracting archive: correct_data.7z
# --
# Path = correct_data.7z
# Type = 7z
# Physical Size = 60689089
# Headers Size = 30151
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 12
# Files: 2727
# Size:       62459394
# Compressed: 60689089

# %% [markdown]
# ## Set hyperparameters

# %%
IMG_WIDTH, IMG_HEIGHT = 224, 224
EPOCHS = 60
BATCH_SIZE= 60
n_classes = 3

# %% [markdown]
# ## Initialize train and test data

# %%
DATA_PATH = '/content/drive/MyDrive/PlateDataset/correct_data/'

TRAIN_PATH = DATA_PATH + 'train'

VALIDATION_PATH = DATA_PATH + 'validation'

TEST_PATH = DATA_PATH + 'test'

# %% [markdown]
# ## An example from dataset

# %%
image = mpimg.imread(os.path.join(DATA_PATH, 'train/0/0053.jpg'))
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Implementations

# %%
def recall_m(y_true, y_pred):
    K = tf.keras.backend
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    K = tf.keras.backend
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    K = tf.keras.backend
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ## Create generator

# %%
train_datagen_aug = ImageDataGenerator(preprocessing_function=preprocess_input,
                                      shear_range=0.25,
                                      width_shift_range=0.25,
                                      height_shift_range=0.25,
                                      zoom_range=0.2,
                                      rotation_range=40)

validation_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator_aug  = train_datagen_aug.flow_from_directory(TRAIN_PATH,
                                                              target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                              batch_size=BATCH_SIZE,
                                                              class_mode='categorical')
validation_generator  = validation_datagen.flow_from_directory(VALIDATION_PATH,
                                                              target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                              batch_size=BATCH_SIZE,
                                                              class_mode='categorical')
test_generator = test_datagen.flow_from_directory(TEST_PATH,
                                                  target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                  batch_size=BATCH_SIZE,
                                                  shuffle=False,
                                                  class_mode='categorical')
# Out:
# Found 2180 images belonging to 3 classes.
# Found 271 images belonging to 3 classes.
# Found 276 images belonging to 3 classes.

# %% [markdown]
# ## Define model

# %%
def build_model():
  baseModel = Xception(
        include_top=False,
        weights="imagenet",
        input_tensor=Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        pooling='avg'
    )
    
  # for layer in baseModel.layers:
  #     layer.trainable = False
  # for layer in baseModel.layers[-40:]:
  #     layer.trainable = True

  headModel = baseModel.output
  headModel = Dropout(0.2)(headModel)
  headModel = Dense(1024, activation="relu")(headModel)
  headModel = Dropout(0.2)(headModel)
  headModel = Dense(1024, activation="relu")(headModel)
  headModel = Dropout(0.2)(headModel)
  headModel = Dense(512, activation="relu")(headModel)
  headModel = Dropout(0.2)(headModel)
  headModel = Dense(512, activation="relu")(headModel)
  headModel = Dropout(0.2)(headModel)
  headModel = Dense(n_classes, activation="softmax")(headModel)
  
  model = Model(inputs=baseModel.input, outputs=headModel)

  return model

# %% [markdown]
# ## Compile and fit model

# %%
# learning_rate = 0.0001
weights = '/content/drive/MyDrive/PlateDatasetModels/Xception_correctDataset_weights.h5'
callbacks = [ 
            #  EarlyStopping(monitor='val_f1_m', patience=20, verbose=0), 
              ModelCheckpoint(weights, monitor='val_f1_m', save_best_only=True, verbose=0, mode='max')
              # ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=20, verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)]
            ]
loss = CategoricalCrossentropy()
# optimizer = SGD(lr=1e-2, momentum=0.9, decay=1e-2/40)
optimizer = Adam()
model = build_model()
model.compile(
    loss=loss, 
    optimizer=optimizer, 
    metrics=['accuracy', f1_m, precision_m, recall_m],
)

history = model.fit(
    train_generator_aug, 
    validation_data=validation_generator, 
    epochs=EPOCHS, 
    batch_size=BATCH_SIZE, 
    callbacks=callbacks
)
# Out:
# Epoch 1/60
# 37/37 [==============================] - 109s 3s/step - loss: 0.7109 - accuracy: 0.6904 - f1_m: 0.6206 - precision_m: 0.7572 - recall_m: 0.5313 - val_loss: 4.8666 - val_accuracy: 0.6974 - val_f1_m: 0.7122 - val_precision_m: 0.7133 - val_recall_m: 0.7111
# Epoch 2/60
# 37/37 [==============================] - 93s 2s/step - loss: 0.3713 - accuracy: 0.8661 - f1_m: 0.8626 - precision_m: 0.8813 - recall_m: 0.8451 - val_loss: 7.8284 - val_accuracy: 0.7970 - val_f1_m: 0.7987 - val_precision_m: 0.8030 - val_recall_m: 0.7946
# Epoch 3/60
# 37/37 [==============================] - 93s 2s/step - loss: 0.2990 - accuracy: 0.8793 - f1_m: 0.8834 - precision_m: 0.9019 - recall_m: 0.8662 - val_loss: 1.1509 - val_accuracy: 0.8339 - val_f1_m: 0.8198 - val_precision_m: 0.8242 - val_recall_m: 0.8155
# Epoch 4/60
# 37/37 [==============================] - 93s 2s/step - loss: 0.2170 - accuracy: 0.8922 - f1_m: 0.9009 - precision_m: 0.9241 - recall_m: 0.8798 - val_loss: 0.9714 - val_accuracy: 0.8708 - val_f1_m: 0.8734 - val_precision_m: 0.8792 - val_recall_m: 0.8677
# Epoch 5/60
# 37/37 [==============================] - 93s 2s/step - loss: 0.1969 - accuracy: 0.9179 - f1_m: 0.9182 - precision_m: 0.9304 - recall_m: 0.9066 - val_loss: 0.6777 - val_accuracy: 0.8745 - val_f1_m: 0.8693 - val_precision_m: 0.8708 - val_recall_m: 0.8677
# Epoch 6/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.1958 - accuracy: 0.9346 - f1_m: 0.9304 - precision_m: 0.9415 - recall_m: 0.9203 - val_loss: 2.7293 - val_accuracy: 0.8708 - val_f1_m: 0.8623 - val_precision_m: 0.8668 - val_recall_m: 0.8580
# Epoch 7/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.1363 - accuracy: 0.9597 - f1_m: 0.9596 - precision_m: 0.9620 - recall_m: 0.9573 - val_loss: 4.1554 - val_accuracy: 0.5572 - val_f1_m: 0.5699 - val_precision_m: 0.5745 - val_recall_m: 0.5655
# Epoch 8/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.1470 - accuracy: 0.9541 - f1_m: 0.9536 - precision_m: 0.9569 - recall_m: 0.9504 - val_loss: 1.0222 - val_accuracy: 0.8598 - val_f1_m: 0.8542 - val_precision_m: 0.8572 - val_recall_m: 0.8513
# Epoch 9/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.1425 - accuracy: 0.9638 - f1_m: 0.9636 - precision_m: 0.9668 - recall_m: 0.9604 - val_loss: 0.6769 - val_accuracy: 0.8672 - val_f1_m: 0.8597 - val_precision_m: 0.8612 - val_recall_m: 0.8582
# Epoch 10/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.1133 - accuracy: 0.9782 - f1_m: 0.9742 - precision_m: 0.9802 - recall_m: 0.9685 - val_loss: 0.2942 - val_accuracy: 0.9299 - val_f1_m: 0.9269 - val_precision_m: 0.9301 - val_recall_m: 0.9238
# Epoch 11/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.1280 - accuracy: 0.9622 - f1_m: 0.9606 - precision_m: 0.9668 - recall_m: 0.9546 - val_loss: 1.0138 - val_accuracy: 0.9004 - val_f1_m: 0.8928 - val_precision_m: 0.8944 - val_recall_m: 0.8913
# Epoch 12/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0766 - accuracy: 0.9754 - f1_m: 0.9768 - precision_m: 0.9797 - recall_m: 0.9740 - val_loss: 0.2780 - val_accuracy: 0.9225 - val_f1_m: 0.9253 - val_precision_m: 0.9268 - val_recall_m: 0.9238
# Epoch 13/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0684 - accuracy: 0.9788 - f1_m: 0.9783 - precision_m: 0.9794 - recall_m: 0.9773 - val_loss: 0.3995 - val_accuracy: 0.9299 - val_f1_m: 0.9316 - val_precision_m: 0.9363 - val_recall_m: 0.9271
# Epoch 14/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0741 - accuracy: 0.9788 - f1_m: 0.9785 - precision_m: 0.9790 - recall_m: 0.9781 - val_loss: 1.2350 - val_accuracy: 0.8450 - val_f1_m: 0.8402 - val_precision_m: 0.8457 - val_recall_m: 0.8348
# Epoch 15/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.1237 - accuracy: 0.9727 - f1_m: 0.9728 - precision_m: 0.9749 - recall_m: 0.9708 - val_loss: 0.1867 - val_accuracy: 0.9483 - val_f1_m: 0.9418 - val_precision_m: 0.9496 - val_recall_m: 0.9342
# Epoch 16/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0743 - accuracy: 0.9791 - f1_m: 0.9799 - precision_m: 0.9810 - recall_m: 0.9789 - val_loss: 0.1840 - val_accuracy: 0.9557 - val_f1_m: 0.9519 - val_precision_m: 0.9568 - val_recall_m: 0.9471
# Epoch 17/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0539 - accuracy: 0.9859 - f1_m: 0.9821 - precision_m: 0.9833 - recall_m: 0.9808 - val_loss: 0.1131 - val_accuracy: 0.9557 - val_f1_m: 0.9585 - val_precision_m: 0.9600 - val_recall_m: 0.9569
# Epoch 18/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0621 - accuracy: 0.9867 - f1_m: 0.9863 - precision_m: 0.9877 - recall_m: 0.9849 - val_loss: 0.3818 - val_accuracy: 0.9114 - val_f1_m: 0.9214 - val_precision_m: 0.9229 - val_recall_m: 0.9200
# Epoch 19/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0778 - accuracy: 0.9738 - f1_m: 0.9744 - precision_m: 0.9771 - recall_m: 0.9719 - val_loss: 0.3080 - val_accuracy: 0.9151 - val_f1_m: 0.9230 - val_precision_m: 0.9261 - val_recall_m: 0.9200
# Epoch 20/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.1110 - accuracy: 0.9751 - f1_m: 0.9746 - precision_m: 0.9752 - recall_m: 0.9739 - val_loss: 0.2631 - val_accuracy: 0.9225 - val_f1_m: 0.9206 - val_precision_m: 0.9206 - val_recall_m: 0.9206
# Epoch 21/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0753 - accuracy: 0.9785 - f1_m: 0.9790 - precision_m: 0.9790 - recall_m: 0.9789 - val_loss: 0.1017 - val_accuracy: 0.9668 - val_f1_m: 0.9683 - val_precision_m: 0.9699 - val_recall_m: 0.9667
# Epoch 22/60
# 37/37 [==============================] - 93s 2s/step - loss: 0.0702 - accuracy: 0.9793 - f1_m: 0.9786 - precision_m: 0.9799 - recall_m: 0.9774 - val_loss: 0.3024 - val_accuracy: 0.9483 - val_f1_m: 0.9456 - val_precision_m: 0.9473 - val_recall_m: 0.9440
# Epoch 23/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0579 - accuracy: 0.9823 - f1_m: 0.9822 - precision_m: 0.9833 - recall_m: 0.9812 - val_loss: 0.1235 - val_accuracy: 0.9557 - val_f1_m: 0.9561 - val_precision_m: 0.9725 - val_recall_m: 0.9404
# Epoch 24/60
# 37/37 [==============================] - 93s 2s/step - loss: 0.0503 - accuracy: 0.9834 - f1_m: 0.9842 - precision_m: 0.9848 - recall_m: 0.9836 - val_loss: 0.4957 - val_accuracy: 0.9004 - val_f1_m: 0.8975 - val_precision_m: 0.8975 - val_recall_m: 0.8975
# Epoch 25/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0838 - accuracy: 0.9766 - f1_m: 0.9768 - precision_m: 0.9785 - recall_m: 0.9751 - val_loss: 0.1948 - val_accuracy: 0.9410 - val_f1_m: 0.9385 - val_precision_m: 0.9432 - val_recall_m: 0.9340
# Epoch 26/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0734 - accuracy: 0.9817 - f1_m: 0.9813 - precision_m: 0.9828 - recall_m: 0.9798 - val_loss: 0.3709 - val_accuracy: 0.8782 - val_f1_m: 0.8694 - val_precision_m: 0.8708 - val_recall_m: 0.8680
# Epoch 27/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0894 - accuracy: 0.9787 - f1_m: 0.9795 - precision_m: 0.9802 - recall_m: 0.9788 - val_loss: 0.1657 - val_accuracy: 0.9594 - val_f1_m: 0.9504 - val_precision_m: 0.9533 - val_recall_m: 0.9475
# Epoch 28/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0271 - accuracy: 0.9939 - f1_m: 0.9940 - precision_m: 0.9941 - recall_m: 0.9939 - val_loss: 0.1226 - val_accuracy: 0.9631 - val_f1_m: 0.9620 - val_precision_m: 0.9637 - val_recall_m: 0.9604
# Epoch 29/60
# 37/37 [==============================] - 93s 2s/step - loss: 0.0300 - accuracy: 0.9896 - f1_m: 0.9897 - precision_m: 0.9897 - recall_m: 0.9897 - val_loss: 0.1496 - val_accuracy: 0.9705 - val_f1_m: 0.9733 - val_precision_m: 0.9733 - val_recall_m: 0.9733
# Epoch 30/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0307 - accuracy: 0.9929 - f1_m: 0.9931 - precision_m: 0.9932 - recall_m: 0.9930 - val_loss: 0.1744 - val_accuracy: 0.9557 - val_f1_m: 0.9569 - val_precision_m: 0.9569 - val_recall_m: 0.9569
# Epoch 31/60
# 37/37 [==============================] - 92s 3s/step - loss: 0.0800 - accuracy: 0.9841 - f1_m: 0.9822 - precision_m: 0.9822 - recall_m: 0.9822 - val_loss: 0.1027 - val_accuracy: 0.9705 - val_f1_m: 0.9671 - val_precision_m: 0.9671 - val_recall_m: 0.9671
# Epoch 32/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0171 - accuracy: 0.9922 - f1_m: 0.9925 - precision_m: 0.9928 - recall_m: 0.9923 - val_loss: 0.2840 - val_accuracy: 0.9705 - val_f1_m: 0.9701 - val_precision_m: 0.9734 - val_recall_m: 0.9669
# Epoch 33/60
# 37/37 [==============================] - 93s 2s/step - loss: 0.0728 - accuracy: 0.9838 - f1_m: 0.9847 - precision_m: 0.9866 - recall_m: 0.9828 - val_loss: 0.1230 - val_accuracy: 0.9705 - val_f1_m: 0.9703 - val_precision_m: 0.9737 - val_recall_m: 0.9671
# Epoch 34/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0427 - accuracy: 0.9909 - f1_m: 0.9896 - precision_m: 0.9923 - recall_m: 0.9869 - val_loss: 0.2224 - val_accuracy: 0.9557 - val_f1_m: 0.9536 - val_precision_m: 0.9569 - val_recall_m: 0.9504
# Epoch 35/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0449 - accuracy: 0.9882 - f1_m: 0.9892 - precision_m: 0.9928 - recall_m: 0.9858 - val_loss: 0.5329 - val_accuracy: 0.8192 - val_f1_m: 0.8242 - val_precision_m: 0.8242 - val_recall_m: 0.8242
# Epoch 36/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0534 - accuracy: 0.9854 - f1_m: 0.9853 - precision_m: 0.9858 - recall_m: 0.9849 - val_loss: 0.1012 - val_accuracy: 0.9668 - val_f1_m: 0.9669 - val_precision_m: 0.9669 - val_recall_m: 0.9669
# Epoch 37/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0356 - accuracy: 0.9918 - f1_m: 0.9911 - precision_m: 0.9918 - recall_m: 0.9905 - val_loss: 0.2042 - val_accuracy: 0.9594 - val_f1_m: 0.9618 - val_precision_m: 0.9635 - val_recall_m: 0.9602
# Epoch 38/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0289 - accuracy: 0.9928 - f1_m: 0.9933 - precision_m: 0.9943 - recall_m: 0.9924 - val_loss: 0.4875 - val_accuracy: 0.9151 - val_f1_m: 0.9171 - val_precision_m: 0.9171 - val_recall_m: 0.9171
# Epoch 39/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0759 - accuracy: 0.9764 - f1_m: 0.9757 - precision_m: 0.9773 - recall_m: 0.9740 - val_loss: 0.3219 - val_accuracy: 0.9483 - val_f1_m: 0.9533 - val_precision_m: 0.9533 - val_recall_m: 0.9533
# Epoch 40/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0363 - accuracy: 0.9926 - f1_m: 0.9926 - precision_m: 0.9927 - recall_m: 0.9926 - val_loss: 0.2872 - val_accuracy: 0.9668 - val_f1_m: 0.9700 - val_precision_m: 0.9700 - val_recall_m: 0.9700
# Epoch 41/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0312 - accuracy: 0.9940 - f1_m: 0.9947 - precision_m: 0.9953 - recall_m: 0.9942 - val_loss: 0.2142 - val_accuracy: 0.9483 - val_f1_m: 0.9486 - val_precision_m: 0.9502 - val_recall_m: 0.9471
# Epoch 42/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0415 - accuracy: 0.9922 - f1_m: 0.9921 - precision_m: 0.9933 - recall_m: 0.9909 - val_loss: 0.2349 - val_accuracy: 0.9631 - val_f1_m: 0.9635 - val_precision_m: 0.9635 - val_recall_m: 0.9635
# Epoch 43/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0173 - accuracy: 0.9950 - f1_m: 0.9950 - precision_m: 0.9950 - recall_m: 0.9950 - val_loss: 0.2228 - val_accuracy: 0.9705 - val_f1_m: 0.9733 - val_precision_m: 0.9733 - val_recall_m: 0.9733
# Epoch 44/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0456 - accuracy: 0.9893 - f1_m: 0.9890 - precision_m: 0.9895 - recall_m: 0.9886 - val_loss: 0.1006 - val_accuracy: 0.9705 - val_f1_m: 0.9733 - val_precision_m: 0.9733 - val_recall_m: 0.9733
# Epoch 45/60
# 37/37 [==============================] - 93s 2s/step - loss: 0.0375 - accuracy: 0.9840 - f1_m: 0.9839 - precision_m: 0.9840 - recall_m: 0.9838 - val_loss: 0.2705 - val_accuracy: 0.9594 - val_f1_m: 0.9477 - val_precision_m: 0.9477 - val_recall_m: 0.9477
# Epoch 46/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0331 - accuracy: 0.9907 - f1_m: 0.9901 - precision_m: 0.9915 - recall_m: 0.9888 - val_loss: 0.1106 - val_accuracy: 0.9705 - val_f1_m: 0.9750 - val_precision_m: 0.9766 - val_recall_m: 0.9733
# Epoch 47/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0479 - accuracy: 0.9906 - f1_m: 0.9908 - precision_m: 0.9910 - recall_m: 0.9906 - val_loss: 0.1241 - val_accuracy: 0.9594 - val_f1_m: 0.9616 - val_precision_m: 0.9633 - val_recall_m: 0.9600
# Epoch 48/60
# 37/37 [==============================] - 93s 2s/step - loss: 0.0110 - accuracy: 0.9964 - f1_m: 0.9973 - precision_m: 0.9983 - recall_m: 0.9964 - val_loss: 0.2363 - val_accuracy: 0.9594 - val_f1_m: 0.9633 - val_precision_m: 0.9633 - val_recall_m: 0.9633
# Epoch 49/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0237 - accuracy: 0.9938 - f1_m: 0.9939 - precision_m: 0.9940 - recall_m: 0.9939 - val_loss: 0.1330 - val_accuracy: 0.9631 - val_f1_m: 0.9650 - val_precision_m: 0.9666 - val_recall_m: 0.9633
# Epoch 50/60
# 37/37 [==============================] - 93s 2s/step - loss: 0.0357 - accuracy: 0.9874 - f1_m: 0.9884 - precision_m: 0.9891 - recall_m: 0.9876 - val_loss: 0.0964 - val_accuracy: 0.9742 - val_f1_m: 0.9750 - val_precision_m: 0.9766 - val_recall_m: 0.9733
# Epoch 51/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0252 - accuracy: 0.9939 - f1_m: 0.9951 - precision_m: 0.9962 - recall_m: 0.9940 - val_loss: 0.2552 - val_accuracy: 0.9631 - val_f1_m: 0.9604 - val_precision_m: 0.9604 - val_recall_m: 0.9604
# Epoch 52/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0284 - accuracy: 0.9924 - f1_m: 0.9913 - precision_m: 0.9915 - recall_m: 0.9911 - val_loss: 0.2045 - val_accuracy: 0.9668 - val_f1_m: 0.9749 - val_precision_m: 0.9798 - val_recall_m: 0.9700
# Epoch 53/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0242 - accuracy: 0.9948 - f1_m: 0.9928 - precision_m: 0.9937 - recall_m: 0.9919 - val_loss: 0.1018 - val_accuracy: 0.9742 - val_f1_m: 0.9750 - val_precision_m: 0.9798 - val_recall_m: 0.9702
# Epoch 54/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0120 - accuracy: 0.9986 - f1_m: 0.9978 - precision_m: 0.9987 - recall_m: 0.9969 - val_loss: 1.0371 - val_accuracy: 0.9188 - val_f1_m: 0.9186 - val_precision_m: 0.9201 - val_recall_m: 0.9171
# Epoch 55/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0910 - accuracy: 0.9868 - f1_m: 0.9855 - precision_m: 0.9864 - recall_m: 0.9846 - val_loss: 0.3141 - val_accuracy: 0.9631 - val_f1_m: 0.9618 - val_precision_m: 0.9634 - val_recall_m: 0.9602
# Epoch 56/60
# 37/37 [==============================] - 93s 2s/step - loss: 0.0586 - accuracy: 0.9890 - f1_m: 0.9899 - precision_m: 0.9909 - recall_m: 0.9889 - val_loss: 0.8040 - val_accuracy: 0.7454 - val_f1_m: 0.7547 - val_precision_m: 0.7861 - val_recall_m: 0.7259
# Epoch 57/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0339 - accuracy: 0.9891 - f1_m: 0.9873 - precision_m: 0.9898 - recall_m: 0.9850 - val_loss: 0.4786 - val_accuracy: 0.8893 - val_f1_m: 0.8776 - val_precision_m: 0.8910 - val_recall_m: 0.8646
# Epoch 58/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0464 - accuracy: 0.9865 - f1_m: 0.9873 - precision_m: 0.9880 - recall_m: 0.9866 - val_loss: 0.1712 - val_accuracy: 0.9410 - val_f1_m: 0.9388 - val_precision_m: 0.9403 - val_recall_m: 0.9373
# Epoch 59/60
# 37/37 [==============================] - 93s 2s/step - loss: 0.0430 - accuracy: 0.9894 - f1_m: 0.9887 - precision_m: 0.9902 - recall_m: 0.9872 - val_loss: 0.1379 - val_accuracy: 0.9520 - val_f1_m: 0.9580 - val_precision_m: 0.9628 - val_recall_m: 0.9533
# Epoch 60/60
# 37/37 [==============================] - 92s 2s/step - loss: 0.0298 - accuracy: 0.9942 - f1_m: 0.9938 - precision_m: 0.9944 - recall_m: 0.9932 - val_loss: 0.1538 - val_accuracy: 0.9557 - val_f1_m: 0.9600 - val_precision_m: 0.9633 - val_recall_m: 0.9569

# %% [markdown]
# ## Compile and fit model

# %%
best_model = tf.keras.models.load_model(weights, custom_objects={'f1_m':f1_m, 'precision_m':precision_m, 'recall_m':recall_m})
best_model.compile(
    loss=loss, 
    optimizer=optimizer, 
    metrics=['accuracy', f1_m, precision_m, recall_m]
)

# %%
best_model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 5/5 [==============================] - 3s 564ms/step - loss: 0.0877 - accuracy: 0.9819 - f1_m: 0.9833 - precision_m: 0.9833 - recall_m: 0.9833
# [0.08772743493318558,
#  0.9818840622901917,
#  0.9833332896232605,
#  0.98333340883255,
#  0.98333340883255]

# %% [markdown]
# ## Save model

# %%
best_model.save("/content/drive/MyDrive/PlateDatasetModels/Xception-newDataset.h5")

# %% [markdown]
# ## Get Reports

# %%
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = best_model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(test_generator.classes, y_pred))
print('Classification Report')
target_names = ['0', '1', '2']
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[189   0   0]
#  [  4  24   1]
#  [  0   0  58]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       189
#            1       1.00      0.83      0.91        29
#            2       0.98      1.00      0.99        58
#
#     accuracy                           0.98       276
#    macro avg       0.99      0.94      0.96       276
# weighted avg       0.98      0.98      0.98       276
